# %% [markdown]
# # Importing libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#import dataframe
ords_prods_merge = pd.read_pickle(r'/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_merge_derived.pkl')

# %%
ords_prods_merge.shape
# Out:
# (30328763, 18)

# %%
#check to see if its right data frame and contains newly derived columns
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                  3                  7
# 1   2398795        1             2                  3                  7
# 2   2398795        1             2                  3                  7
# 3   2398795        1             2                  3                  7
# 4   2398795        1             2                  3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    15.0       10258                  2          0
# 2                    15.0       12427                  3          1
# 3                    15.0       13176                  4          0
# 4                    15.0       26088                  5          1
#
#                  product_name  aisle_id  department_id  prices match  \
# ...

# %%
#find the aggregated mean of the “order_number” column grouped by “department_id”
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.559358
# 2                18.413176
# 3                18.279600
# 4                18.915890
# 5                16.497751
# 6                17.609390
# 7                18.303975
# 8                16.383301
# 9                17.022963
# 10               21.227447
# 11               17.311768
# 12               16.953613
# 13               17.727470
# 14               17.898097
# 15               17.290123
# 16               18.757796
# 17               16.808683
# 18               20.336389
# 19               18.258620
# 20               17.578959
# 21               23.644477

# %% [markdown]
# # How do these results from the subset compare against results from the entire dataframe
# The mean 'order_number' values for the subset are generally lower compared to that of the entire dataset.
# Department 21 has the highest mean value in both data sets.
# The entire dataset provides a more accurate representation of the 'order_number' accross all departments by representing the overall order pattern than the subset which is likely narrower in scope and excludes certain transactions.

# %%
ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Aggregating ords_prods_merge with the transform function 
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/g0/3g_bmqwx1ks0wzpxgh5vgbfm0000gn/T/ipykernel_60805/4180060956.py:2: FutureWarning: The provided callable <function max at 0x110c3a660> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#checking output
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2398795        1             2                  3                  7
# 1    2398795        1             2                  3                  7
# 2    2398795        1             2                  3                  7
# 3    2398795        1             2                  3                  7
# 4    2398795        1             2                  3                  7
# ..       ...      ...           ...                ...                ...
# 95   1199898        2             6                  2                  9
# 96   1199898        2             6                  2                  9
# 97   1199898        2             6                  2                  9
# 98   1199898        2             6                  2                  9
# 99   1199898        2             6                  2                  9
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
#create a loyalty label using loc function 
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#examining the value counts on loyalty_flag
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: count, dtype: int64

# %%
#checking updated df 
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                  3                  7
# 1   2398795        1             2                  3                  7
# 2   2398795        1             2                  3                  7
# 3   2398795        1             2                  3                  7
# 4   2398795        1             2                  3                  7
# 5   2398795        1             2                  3                  7
# 6    473747        1             3                  3                 12
# 7    473747        1             3                  3                 12
# 8    473747        1             3                  3                 12
# 9    473747        1             3                  3                 12
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# ...

# %%
#Determining basic statistics of the products prices for each loyalty category
ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean','min','max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.402162  1.0  99999.0
# New customer      13.396333  1.0  99999.0
# Regular customer  12.546842  1.0  99999.0

# %% [markdown]
# # Spending habits
# Loyal customers spend the least on average (10.40), new customers the most (13.40), and regular customers fall in between (12.55). This suggests loyal customers prefer affordability, while new customers explore higher-priced items. Further analysis could refine insights by addressing outliers like the maximum price of 99999.

# %%
#create a agg of the average prices accross orders 
ords_prods_merge['avg_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/g0/3g_bmqwx1ks0wzpxgh5vgbfm0000gn/T/ipykernel_60805/3044266404.py:2: FutureWarning: The provided callable <function mean at 0x110c3b060> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['avg_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
#checking the new column 
ords_prods_merge[['user_id', 'avg_product_price']].head(15)
# Out:
#     user_id  avg_product_price
# 0         1           6.372222
# 1         1           6.372222
# 2         1           6.372222
# 3         1           6.372222
# 4         1           6.372222
# 5         1           6.372222
# 6         1           6.372222
# 7         1           6.372222
# 8         1           6.372222
# 9         1           6.372222
# 10        1           6.372222
# 11        1           6.372222
# 12        1           6.372222
# 13        1           6.372222
# 14        1           6.372222

# %%
# Creating a 'Spending' Label Flag using loc Function
ords_prods_merge.loc[ords_prods_merge['avg_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
#examing the spending flag column 
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     29730505
# High spender      598258
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'avg_product_price', 'spending_flag']].head(15)
# Out:
#     user_id  avg_product_price spending_flag
# 0         1           6.372222   Low spender
# 1         1           6.372222   Low spender
# 2         1           6.372222   Low spender
# 3         1           6.372222   Low spender
# 4         1           6.372222   Low spender
# 5         1           6.372222   Low spender
# 6         1           6.372222   Low spender
# 7         1           6.372222   Low spender
# 8         1           6.372222   Low spender
# 9         1           6.372222   Low spender
# 10        1           6.372222   Low spender
# 11        1           6.372222   Low spender
# 12        1           6.372222   Low spender
# 13        1           6.372222   Low spender
# 14        1           6.372222   Low spender

# %%
# Aggregating Data with transform() Function
ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# /var/folders/g0/3g_bmqwx1ks0wzpxgh5vgbfm0000gn/T/ipykernel_60805/981590324.py:2: FutureWarning: The provided callable <function median at 0x111259d00> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Checking Relevant Columns 
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders']].head(15)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders
# 0         1                    15.0                        20.5
# 1         1                    15.0                        20.5
# 2         1                    15.0                        20.5
# 3         1                    15.0                        20.5
# 4         1                    15.0                        20.5
# 5         1                    15.0                        20.5
# 6         1                    21.0                        20.5
# 7         1                    21.0                        20.5
# 8         1                    21.0                        20.5
# 9         1                    21.0                        20.5
# 10        1                    21.0                        20.5
# 11        1                    29.0                        20.5
# 12        1                    29.0                        20.5
# 13        1                    29.0                        20.5
# ...

# %%
# Creating a 'Order Frequency' Label Flag using loc Function
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['median_days_between_orders'] <= 20) & (ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Examining Value Counts on 'order_frequency_flag'
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        20675290
# Regular customer          6594542
# Non-frequent customer     3058931
# Name: count, dtype: int64

# %%
# Checking Relevant Columns of Updated Dataframe
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'order_frequency_flag']].head(15)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders  \
# 0         1                    15.0                        20.5
# 1         1                    15.0                        20.5
# 2         1                    15.0                        20.5
# 3         1                    15.0                        20.5
# 4         1                    15.0                        20.5
# 5         1                    15.0                        20.5
# 6         1                    21.0                        20.5
# 7         1                    21.0                        20.5
# 8         1                    21.0                        20.5
# 9         1                    21.0                        20.5
# 10        1                    21.0                        20.5
# 11        1                    29.0                        20.5
# 12        1                    29.0                        20.5
# 13        1                    29.0                        20.5
# ...

# %% [markdown]
# # Export

# %%
ords_prods_merge.to_pickle('/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/ord_prods_grouped.pkl')
