# %% [markdown]
# # Importing libraries

# %%
#import libraries
import pandas as pd
import numpy as np 
import os

# %%
#import customers data frame 
df_cus= pd.read_csv(r'/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Original Data/customers.csv', index_col=False)

# %% [markdown]
# # Data Wraggling & Consistency check

# %%
df_cus.head(5)
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
#check for missing values 
df_cus.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surnam              0
# Gender              0
# STATE               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
# No need to take out missing first name as Last name should be sufficient

# %%
df_cus.shape
# Out:
# (206209, 10)

# %%
df_cus.columns
# Out:
# Index(['user_id', 'First Name', 'Surnam', 'Gender', 'STATE', 'Age',
#        'date_joined', 'n_dependants', 'fam_status', 'income'],
#       dtype='object')

# %%
#renaming columns, spell checking and using proper casing 
df_cus.rename(columns={'Surnam' : 'Last Name', 
                       'STATE' : 'State',
                       'date_joined': 'Date Joined',
                       'n_dependants' : 'number of dependants',
                       'fam_status' : 'Family Status',
                       'income' : 'Income'}, inplace = True )

# %%
#check to see if change has occured in columns 
df_cus.columns
# Out:
# Index(['user_id', 'First Name', 'Last Name', 'Gender', 'State', 'Age',
#        'Date Joined', 'number of dependants', 'Family Status', 'Income'],
#       dtype='object')

# %%
#check to see table description 
df_cus.describe()
# Out:
#              user_id            Age  number of dependants         Income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %%
# check for duplicates 
df_cus[df_cus.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, State, Age, Date Joined, number of dependants, Family Status, Income]
# Index: []

# %%
# No duplicates

# %%
#checking to see data types
df_cus.dtypes
# Out:
# user_id                  int64
# First Name              object
# Last Name               object
# Gender                  object
# State                   object
# Age                      int64
# Date Joined             object
# number of dependants     int64
# Family Status           object
# Income                   int64
# dtype: object

# %%
# None of the data types need changing

# %% [markdown]
# # Combining Customer and Orders&Products Data frame

# %%
#importing ords_products df
ords_prods_merge=pd.read_pickle(r'/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/ord_prods_grouped.pkl')

# %%
#combining both Data frames
df_fullmerged = df_cus.merge(ords_prods_merge, on = 'user_id', how = 'inner')

# %%
#checking to see merge 
df_fullmerged.head()
# Out:
#    user_id First Name Last Name  Gender     State  Age Date Joined  \
# 0    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 1    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 2    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 3    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 4    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
#
#    number of dependants Family Status  Income  ...    price_range_loc  \
# 0                     3       married  165665  ...  Mid-range product
# 1                     3       married  165665  ...  Mid-range product
# 2                     3       married  165665  ...  Low-range product
# 3                     3       married  165665  ...  Mid-range product
# 4                     3       married  165665  ...  Mid-range product
#
#       busiest_day    busiest_days  busiest_period_of_day  max_order  \
# 0  Regularly busy  Regularly busy            Most orders          8
# ...

# %%
#seeing full rows and columns 
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
df_fullmerged.head()
# Out:
#    user_id First Name Last Name  Gender     State  Age Date Joined  \
# 0    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 1    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 2    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 3    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 4    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
#
#    number of dependants Family Status  Income  order_id  order_number  \
# 0                     3       married  165665    423547             2
# 1                     3       married  165665   2524893             3
# 2                     3       married  165665   2524893             3
# 3                     3       married  165665   2524893             3
# 4                     3       married  165665   2984525             4
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
df_fullmerged.shape
# Out:
# (30328763, 33)

# %% [markdown]
# # Exporting Data

# %%
df_fullmerged.to_pickle('/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_cus_merged.pkl')
