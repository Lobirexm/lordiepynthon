# %% [markdown]
# # importing libraries

# %%
#import libraires
import pandas as pd
import numpy as np
import os

# %%
#import orders_products_combined in pkl version
df_orders_products_prior=pd.read_pickle(r'/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl')

# %%
df_orders_products_prior.shape
# Out:
# (32434489, 10)

# %%
#import prepared products wrangled, cleaned and deduped data frame 
df_products_checked=pd.read_csv(r'/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/products_checked.csv', index_col=False)

# %% [markdown]
# # checking data frame structure

# %%
#checking shape and structure of Orders_products_combined data frame 
df_orders_products_prior.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
#checking shape and structure of products_checked data frame 
df_products_checked.shape
# Out:
# (49672, 6)

# %%
df_products_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#dropping the unnamed:0 column
df_products_checked=df_products_checked.drop('Unnamed: 0', axis=1, errors='ignore')

# %%
df_products_checked.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# # merging data frames

# %% [markdown]
# # The connecting column is products_id which is on both data frames, which makes a merge possible, a inner join is appropriate since stand alone it would make sense on its own.

# %%
#merging both tables 
ords_prods_merge=df_orders_products_prior.merge(df_products_checked, on ='product_id', how='inner', indicator='match')

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
# ...

# %%
#droping the _merge column as it does nothing for my analysis 
ords_prods_merge = ords_prods_merge.drop('_merge', axis=1, errors='ignore')

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
ords_prods_merge
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32404854   2977660   206209            13                  1
# 32404855   2977660   206209            13                  1
# 32404856   2977660   206209            13                  1
# 32404857   2977660   206209            13                  1
# 32404858   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
#ords_prods_merge exported to pkl format
ords_prods_merge.to_pickle('/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_merge.pkl')

# %%
ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %%
ords_prods_merge.shape
# Out:
# (32404859, 14)

# %%
ords_prods_merge.duplicated()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 32404854    False
# 32404855    False
# 32404856    False
# 32404857    False
# 32404858    False
# Length: 32404859, dtype: bool

# %%
ords_prods_merge.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# order_day_of_week               0
# order_hour_of_day               0
# days_since_prior_order    2076096
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# product_name                    0
# aisle_id                        0
# department_id                   0
# prices                          0
# match                           0
# dtype: int64
