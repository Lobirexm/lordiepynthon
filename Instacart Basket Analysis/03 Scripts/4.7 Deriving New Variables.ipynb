# %% [markdown]
# # Importing libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#importing data frame
ords_prods_merge=pd.read_pickle(r'/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_merge_redone.pkl')

# %%
#working with a subset of data frame of first 1 million rows 
df=ords_prods_merge[:1000000]

# %%
#define price label
def price_label(row):
    if row['prices'] <=5:
        return 'Low-range product'
    elif(row['prices'] >5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High range'
    else: return 'Not enough data'

# %%
#applying the defined string label to my data frame
df['price_range']=df.apply(price_label, axis =1)
# Out:
# /var/folders/g0/3g_bmqwx1ks0wzpxgh5vgbfm0000gn/T/ipykernel_21026/2428880636.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range']=df.apply(price_label, axis =1)

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                  3                  7
# 1   2398795        1             2                  3                  7
# 2   2398795        1             2                  3                  7
# 3   2398795        1             2                  3                  7
# 4   2398795        1             2                  3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    15.0       10258                  2          0
# 2                    15.0       12427                  3          1
# 3                    15.0       13176                  4          0
# 4                    15.0       26088                  5          1
#
#                  product_name  aisle_id  department_id  prices match  \
# ...

# %%
df['price_range'].value_counts()
# Out:
# price_range
# Mid-range product    672722
# Low-range product    314975
# High range            12303
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#            order_id         user_id    order_number  order_day_of_week  \
# count  1.000000e+06  1000000.000000  1000000.000000     1000000.000000
# mean   1.709134e+06     3514.172087       18.443532           2.771291
# std    9.874661e+05     1986.826924       17.979706           2.090370
# min    8.000000e+00        1.000000        2.000000           0.000000
# 25%    8.587800e+05     1789.000000        6.000000           1.000000
# 50%    1.706802e+06     3580.000000       12.000000           3.000000
# 75%    2.559897e+06     5253.000000       25.000000           5.000000
# max    3.420955e+06     6910.000000       99.000000           6.000000
#
#        order_hour_of_day  days_since_prior_order      product_id  \
# count     1000000.000000          1000000.000000  1000000.000000
# mean           13.406722               11.054589    25598.046348
# std             4.234630                8.808562    14080.636596
# min             0.000000                0.000000        1.000000
# ...

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product    672722
# Low-range product    314975
# High range            12303
# Name: count, dtype: int64

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     20462144
# Low-range product      9476774
# High-range product      389845
# Name: count, dtype: int64

# %%
print("My name is 30")
# Out:
# My name is 30

# %%
print("My age is 31")
# Out:
# My age is 31

# %%
print("My age is 32")
# Out:
# My age is 32

# %%
print("My age is 33")
# Out:
# My age is 33

# %%
for x in range(30,45):
    print("my age is %d" %(x))
# Out:
# my age is 30
# my age is 31
# my age is 32
# my age is 33
# my age is 34
# my age is 35
# my age is 36
# my age is 37
# my age is 38
# my age is 39
# my age is 40
# my age is 41
# my age is 42
# my age is 43
# my age is 44

# %%
ords_prods_merge['order_day_of_week'].value_counts(dropna=False)
# Out:
# order_day_of_week
# 0    5779087
# 1    5303718
# 6    4190948
# 5    3952326
# 2    3947564
# 3    3600589
# 4    3554531
# Name: count, dtype: int64

# %%
result = []
for value in ords_prods_merge["order_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    20995145
# Busiest day        5779087
# Least busy         3554531
# Name: count, dtype: int64

# %%
#observe output for busiest days
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                  3                  7
# 1   2398795        1             2                  3                  7
# 2   2398795        1             2                  3                  7
# 3   2398795        1             2                  3                  7
# 4   2398795        1             2                  3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    15.0       10258                  2          0
# 2                    15.0       12427                  3          1
# 3                    15.0       13176                  4          0
# 4                    15.0       26088                  5          1
#
#                  product_name  aisle_id  department_id  prices match  \
# ...

# %% [markdown]
# # Task 2

# %%
# create column for 2 most busiest days(0,1) and 2 most slowest days(3,4)
result_2 = []
for value in ords_prods_merge["order_day_of_week"]:
  if value == 0 or value == 1:
    result_2.append("Busiest days")
  elif value == 4 or value == 3:
    result_2.append("Least busy")
  else:
    result_2.append("Regularly busy")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # create column for 2 most busiest days(0,1) and 2 most slowest days(3,4)
#       2 result_2 = []
# ----> 3 for value in ords_prods_merge["order_day_of_week"]:
#       4   if value == 0 or value == 1:
#       5     result_2.append("Busiest days")
#
# NameError: name 'ords_prods_merge' is not defined

# %%
result_2
# Out:
# ['Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# # task 3 Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
# create new busiest_days column in ords_prods_merge to view result
ords_prods_merge['busiest_days'] = result_2

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                  3                  7
# 1   2398795        1             2                  3                  7
# 2   2398795        1             2                  3                  7
# 3   2398795        1             2                  3                  7
# 4   2398795        1             2                  3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    15.0       10258                  2          0
# 2                    15.0       12427                  3          1
# 3                    15.0       13176                  4          0
# 4                    15.0       26088                  5          1
#
#                  product_name  aisle_id  department_id  prices match  \
# ...

# %%
ords_prods_merge['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regularly busy    12090838
# Busiest day       11082805
# Least busy         7155120
# Name: count, dtype: int64

# %% [markdown]
# # the sum of both busiest_day and busiest_days returned 30,328,763 , indicating all rows have been successfully allocated.

# %% [markdown]
# # Task 4 When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
#first we check to see the frequency of the most busiest hour
ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2593725
# 11    2564597
# 14    2517238
# 15    2487586
# 13    2487500
# 12    2445841
# 16    2364969
# 9     2311334
# 17    1943858
# 8     1622394
# 18    1520954
# 19    1169224
# 20     910005
# 7      844665
# 21     746254
# 22     592432
# 23     375889
# 6      274801
# 0      203460
# 1      108110
# 5       82706
# 2       63961
# 4       49400
# 3       47860
# Name: count, dtype: int64

# %% [markdown]
# # the hour with the most orders are 10,11,14,15,13,12,16,9. Average orders 17,8,18,19,20,7,21,22. Fewest orders 23,6,0,1,5,2,4,3.

# %%
# create column for the busiest period of the day
result_3 = []
for value in ords_prods_merge["order_hour_of_day"]:
  if value in [10,11,14,15,13,12,16,9]:
    result_3.append("Most orders")
  elif value in [23,6,0,1,5,2,4,3]:
    result_3.append("Fewest orders")
  else:
    result_3.append("Average orders")

# %%
result_3
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
# ...

# %%
#create column on data frame named busiest_period_of_day
ords_prods_merge['busiest_period_of_day'] = result_3

# %%
#check to see on data frame 
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                  3                  7
# 1   2398795        1             2                  3                  7
# 2   2398795        1             2                  3                  7
# 3   2398795        1             2                  3                  7
# 4   2398795        1             2                  3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    15.0       10258                  2          0
# 2                    15.0       12427                  3          1
# 3                    15.0       13176                  4          0
# 4                    15.0       26088                  5          1
#
#                  product_name  aisle_id  department_id  prices match  \
# ...

# %% [markdown]
# # task 5 Print the frequency for this new column.

# %%
#prints the frequency
ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Most orders       19772790
# Average orders     9349786
# Fewest orders      1206187
# Name: count, dtype: int64

# %%
ords_prods_merge.to_pickle('/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_merge_derived.pkl')
