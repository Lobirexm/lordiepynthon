# %%
import pandas as pd 
import numpy as np
import os

# %%
df_ords_prior=pd.read_csv(r'/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Original Data/orders_products_prior.csv', index_col=False)

# %%
df_ords=pd.read_csv(r'/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Original Data/orders.csv', index_col=False)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_dubss= df_ords_prior[df_ords_prior.duplicated()]

# %%
df_dubss
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2539329        1    prior             1                  2
# 1   2398795        1    prior             2                  3
# 2    473747        1    prior             3                  3
# 3   2254736        1    prior             4                  4
# 4    431534        1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords_prior.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
df_ords.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_day_of_week              0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
ords_clean=df_ords[df_ords['days_since_prior_order'].isnull()==False]

# %%
ords_clean
# Out:
#          order_id  user_id eval_set  order_number  order_day_of_week  \
# 1         2398795        1    prior             2                  3
# 2          473747        1    prior             3                  3
# 3         2254736        1    prior             4                  4
# 4          431534        1    prior             5                  4
# 5         3367565        1    prior             6                  2
# ...           ...      ...      ...           ...                ...
# 3421078   2266710   206209    prior            10                  5
# 3421079   1854736   206209    prior            11                  4
# 3421080    626363   206209    prior            12                  1
# 3421081   2977660   206209    prior            13                  1
# 3421082    272231   206209    train            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 1                        7                    15.0
# ...

# %%
ords_clean.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# order_day_of_week         0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %%
ords_clean.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# 5         3367565        1             6                  2
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 1                        7                    15.0
# 2                       12                    21.0
# 3                        7                    29.0
# ...

# %%
ords_clean.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# order_day_of_week         0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %%
ords_clean=ords_clean.drop(columns = ['eval_set'])

# %%
ords_clean.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
ords_clean.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# order_number              0
# order_day_of_week         0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %%
merged_large=ords_clean.merge(df_ords_prior, on = 'order_id', indicator=True)

# %%
merged_large.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                  3                  7
# 1   2398795        1             2                  3                  7
# 2   2398795        1             2                  3                  7
# 3   2398795        1             2                  3                  7
# 4   2398795        1             2                  3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                    15.0         196                  1          1   both
# 1                    15.0       10258                  2          0   both
# 2                    15.0       12427                  3          1   both
# 3                    15.0       13176                  4          0   both
# 4                    15.0       26088                  5          1   both

# %%
merged_large.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# order_number              0
# order_day_of_week         0
# order_hour_of_day         0
# days_since_prior_order    0
# product_id                0
# add_to_cart_order         0
# reordered                 0
# _merge                    0
# dtype: int64

# %%
merged_large.shape
# Out:
# (30356421, 10)

# %%
merged_large['_merge'].value_counts()
# Out:
# _merge
# both          30356421
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
merged_large.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge'],
#       dtype='object')

# %%
df_products_checked=pd.read_csv(r'/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/products_checked.csv', index_col=False)

# %%
df_products_checked.shape
# Out:
# (49672, 6)

# %%
df_products_checked.isnull().sum()
# Out:
# Unnamed: 0       0
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# prices           0
# dtype: int64

# %%
df_products_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_products_checked=df_products_checked.drop('Unnamed: 0', axis=1, errors='ignore')

# %%
df_products_checked.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
ords_prods_merge=merged_large.merge(df_products_checked, on ='product_id', how='inner', indicator='match')

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                  3                  7
# 1   2398795        1             2                  3                  7
# 2   2398795        1             2                  3                  7
# 3   2398795        1             2                  3                  7
# 4   2398795        1             2                  3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    15.0         196                  1          1   both
# 1                    15.0       10258                  2          0   both
# 2                    15.0       12427                  3          1   both
# 3                    15.0       13176                  4          0   both
# 4                    15.0       26088                  5          1   both
#
#                  product_name  aisle_id  department_id  prices match
# ...

# %%
ords_prods_merge.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# order_number              0
# order_day_of_week         0
# order_hour_of_day         0
# days_since_prior_order    0
# product_id                0
# add_to_cart_order         0
# reordered                 0
# _merge                    0
# product_name              0
# aisle_id                  0
# department_id             0
# prices                    0
# match                     0
# dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (30328763, 15)

# %%
ords_prods_merge = ords_prods_merge.drop('_merge', axis=1, errors='ignore')

# %%
ords_prods_merge.shape
# Out:
# (30328763, 14)

# %%
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'match'],
#       dtype='object')

# %%
ords_prods_merge
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2398795        1             2                  3
# 1          2398795        1             2                  3
# 2          2398795        1             2                  3
# 3          2398795        1             2                  3
# 4          2398795        1             2                  3
# ...            ...      ...           ...                ...
# 30328758   2977660   206209            13                  1
# 30328759   2977660   206209            13                  1
# 30328760   2977660   206209            13                  1
# 30328761   2977660   206209            13                  1
# 30328762   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         7                    15.0         196
# 1                         7                    15.0       10258
# ...

# %%
ords_prods_merge.to_pickle('/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_merge_redone.pkl')

# %%
ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.032876e+07  3.032876e+07  3.032876e+07       3.032876e+07
# mean   1.710734e+06  1.029339e+05  1.824729e+01       2.740832e+00
# std    9.872433e+05  5.946847e+04  1.759198e+01       2.087951e+00
# min    2.000000e+00  1.000000e+00  2.000000e+00       0.000000e+00
# 25%    8.561425e+05  5.140900e+04  6.000000e+00       1.000000e+00
# 50%    1.710898e+06  1.025990e+05  1.200000e+01       3.000000e+00
# 75%    2.565509e+06  1.543850e+05  2.500000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01       6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.032876e+07            3.032876e+07  3.032876e+07
# mean        1.341142e+01            1.110408e+01  2.559649e+04
# std         4.246834e+00            8.779064e+00  1.408189e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %%
ords_prods_merge.to_csv('/Users/lordsonobire/Documents/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_merge_redone.csv')

# %%
ords_prods_merge['prices'].max()
# Out:
# 99999.0
